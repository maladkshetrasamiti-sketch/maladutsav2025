# %%
# === CONFIG ===
key = "vivahsamiti"
keyDescription = "Vivah Samiti"
Program_Name = "Meet n Greet - 2"
Team_Name = "Vivah Sahyog Samiti"

mainFolder = f"program\\{key}\\"

karykarta_list = f"program\\{key}\\karykarta.csv"      # CSV must have 'Samiti Member Phone Number'
dashboard_for_adhyakya_csv = f"dashboard_{key}.html"

call_log_data_csv = f"program\\{key}\\call_log_data.csv"  # CSV must have 'Samiti Member Phone Number', 'Contact Name', 'Contact Phone Number', 'Call Status', 'Remarks'

karykarta_assignment_list = f"{mainFolder}karykarta_member_assignment.csv"      # CSV must have 'Samiti Member Phone Number'
karykarta_assignment_list_output_folder = f"{mainFolder}output\\"

github_base_url = "https://maladkshetrasamiti-sketch.github.io/maladutsav2025"  # Replace with your actual GitHub Pages URL
image_path = f"{github_base_url}/{mainFolder}/MPM_logo.png"

form_url_base = "https://docs.google.com/forms/d/e/1FAIpQLSddgJb-7qSWjw4vIjB-6rAddcIrCSTreRmbnNNAst2I_bd8dA/viewform?usp=pp_url"
# event_message_in_person = ("🙏 Jai Mahesh!\n"
#             "Namskar {} ji,\n\n"
#             f"Welcome to *{Program_Name}* 🎉\n\n"
#             "📅 Date: 9 Nov 2025 (Sunday)\n"
#             "🕠 Time: 5:30 PM Onwards\n"
#             "📍 Venue: Maheshwari Plot, Borivali (W)\n\n"
#             "Please confirm your participation using the google form below 👇\n"
#             "https://forms.gle/Asvp6qqAv5utMb1x8 \n\n"
#             "For Marksheet submission:   👇\n"
#             "https://forms.gle/YgKUfYDDkNWTYJHUA \n\n"
#             "if you face any issues with marksheet submission, Whatsapp  # 9820454734\n\n"
#             "For any queries, contact Karykarta \r\n{}.\n\n"
# )

event_message_in_person = (
    "🙏 Jai Shree Krishna\n\n"
    "Dear {} ji,\n\n"
    "Maheshwari Pragati Mandal, Mumbai\n\n"
    "Vivah Sahyog Samiti Presents\n\n"
    "✨ Meet & Greet - 2 ✨\n"
    "Camp Max, Kalote\n\n"
    "A unique extension of our \"Together Forever\" initiative — bringing eligible Maheshwari boys and girls together in a beautiful natural setting to connect, converse, and build meaningful bonds 🌲\n\n"
    "📅 Date: 17-18 January 2026\n"
    "📍 Venue: Camp Max, Kalote\n"
    "🌐 www.thecampmax.com\n\n"
    "🎁 Package Includes:\n"
    "✅ Pickup & Drop from Mumbai\n"
    "✅ All Meals\n"
    "✅ Overnight Stay & Glamping\n\n"
    "🎯 Activities:\n"
    "🔥 Campfire\n"
    "🎸 Music & Karaoke\n"
    "🚣 Kayaking\n"
    "⛺ Adventure & more!\n\n"
    "Register Now 👇\n"
    "https://forms.gle/iSME7QisCrrWydu9A\n\n"
    "📞 Contact:\n"
    "Kalpana Lohiyaa: +91 93230 08960\n\n"
    "Kanta Malpani: +91 93227 33821\n\n"
    "Jyoti Rathi: +91 87793 80780\n\n"
    "Note: Limited Seats, Only 40 boys and 40 Girls\n"
    "Registration on First come first serve basis."
)
        
message_to_karykartas = (f"🌸 जय महेश! 🙏\r\n"
    "प्रिय {} जी,\r\n\r\n"
    f"{Program_Name} के अंतर्गत आपकी calling list नीचे share की जा रही है —\r\n"
    "{}\r\n\r\n"
    "कृपया अपने निर्धारित संपर्कों से सप्रेम बात करें , WhatsApp karen और उन्हें Program main shamil होने के लिए motivate करें 💫\r\n"
    "आपका सहयोग इस आयोजन को सफल बनाने में महत्वपूर्ण है 🙏\r\n\r\n"
    f"– {Team_Name} 🌸"
    )

def html_file_name_samiti_member(name):
    name_link = karykarta_assignment_list_output_folder + f"CL_{key}_{name.replace(' ', '')}.html"
    return name_link

# %%
import requests
def download_sheet(sheet_id: str, gid: str, output_file: str, sheet_name: str) -> bool:
    """Download a Google Sheet as CSV and save it to the specified output file."""
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
    
    try:
        print(f"\nDownloading {sheet_name}...")
        print(f"URL: {url}")
        
        response = requests.get(url, timeout=30)
        response.raise_for_status()
        
        # Save the raw CSV
        with open(output_file, 'wb') as f:
            f.write(response.content)
        
        # Load with pandas to verify it's valid CSV and get row count
        df = pd.read_csv(output_file)
        print(f"✓ Successfully downloaded {len(df)} rows to {output_file}")
        return True
        
    except Exception as e:
        print(f"✗ Failed to download {sheet_name}")
        print(f"Error: {str(e)}")
        return False

sheet_id = "1h_-ZZeH9aSGFPq9Gql44cf14ITW5NyHkMgIkurSx9zs" 
download_sheet(
            sheet_id=sheet_id,
            gid="438434890",
            output_file=mainFolder + "call_log_data.csv",
            sheet_name="call_log_data"
        )
# Out:
# Downloading call_log_data...
# URL: https://docs.google.com/spreadsheets/d/1h_-ZZeH9aSGFPq9Gql44cf14ITW5NyHkMgIkurSx9zs/export?format=csv&gid=438434890
# ✓ Successfully downloaded 241 rows to program\vivahsamiti\call_log_data.csv
# True

# %%
# DASHBOARD 
import pandas as pd
import urllib.parse


# === READ DATA ===
#Samiti Member Name and Samite Member Phone Number
df = pd.read_csv(karykarta_list)
df.columns = df.columns.str.strip()

df.head()
html = f"""
<html>
<head>
<meta charset="UTF-8">
<title>Calling Dashboard For {Program_Name}</title>
<style>
    body {{
        font-family: Arial, sans-serif;
        margin: 20px;
        color: #333;
        background-color: #fff;
    }}
    h2 {{
        text-align: center;
        margin-bottom: 20px;
    }}
    .summary-box {{
        background: #f8f9fa;
        border: 1px solid #dee2e6;
        border-radius: 8px;
        padding: 15px;
        margin: 20px auto;
        max-width: 600px;
        text-align: center;
    }}
    .summary-box p {{
        margin: 5px 0;
        font-size: 16px;
    }}
    .summary-box .highlight {{
        font-weight: bold;
        color: #007bff;
    }}
    table {{
        width: 100%;
        border-collapse: collapse;
        font-size: 14px;
        margin-top: 20px;
    }}
    th, td {{
        border: 1px solid #aaa;
        padding: 8px 10px;
        text-align: center;
    }}
    th {{
        background-color: #f8f8f8;
        font-weight: bold;
    }}
    td.name-cell {{
        text-align: left;
    }}    
    a {{
        color: #007bff;
        text-decoration: none;
    }}
    a:hover {{
        text-decoration: underline;
    }}
    .low-calls {{
        font-weight: bold;
        color: #ff0000;
    }}
    .low-calls a {{
        color: #ff0000;
    }}
</style>
</head>
<body>
    <img src="{image_path}" alt="Malad Kshetra Samiti Logo" style="display:block; margin-left:auto; margin-right:auto; width:100px; height:auto;">
    <h2>📞 Calling Dashboard For {Program_Name}</h2>
"""




# Table start HTML
table_start = """
    <table>
        <tr>
            <th>Samiti Member</th>
            <th>Whats App</th>
            <th>Mobile</th>
            <th>SMS</th>
        </tr>
"""

html = html + table_start

# === ADD ROWS ===
for _, row in df.iterrows():
    samiti_member_name = row["Samiti Member Name"]
    phone = str(row["Samiti Member Phone Number"]).strip()

    # Links
    name_link = html_file_name_samiti_member(samiti_member_name).replace("\\", "/")
    name_link_full = f"{github_base_url}/{name_link}"
    tel_link = f"<a href='tel:+91{phone}'>📞</a>"
    print(name_link_full)
    # WhatsApp message (plain text — HTML tags won't work inside WhatsApp)
    # message = f"Jai Mahesh! \r\n Dear {name} ji, Please find your calling list here: {name_link_full}"
    message = message_to_karykartas.format(samiti_member_name,name_link_full)
    

    # URL encode the message
    encoded_message = urllib.parse.quote_plus(message)

    # WhatsApp link
    whatsapp_link = f"<a href='https://wa.me/91{phone}?text={encoded_message}'>💬</a>"
    sms_link = f'<a href="sms:+91{phone}?body={encoded_message}" target="_blank" onclick="this.style.color=\'green\'">SMS</a>'

    # Final combined link display
    name_with_links = f"<a href='{name_link_full}'>{samiti_member_name}</a></small>"



    html += f"""
        <tr>
            <td>{name_with_links}</td>
            <td>{whatsapp_link}</td>
            <td>{tel_link}</td>
            <td>{sms_link}</td>
        </tr>
    """

html += """
    </table>
</body>
</html>
"""

# === SAVE OUTPUT ===
with open(dashboard_for_adhyakya_csv, "w", encoding="utf-8") as f:
    f.write(html)

print(f"✅ Dashboard created successfully: {dashboard_for_adhyakya_csv}")
# Out:
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_JyotiRathi.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_AshishMundada.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_Shanujikabra.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_Krishnazawar.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_SeemaChitlangia.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_VaroonJajoo.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_KantaMalpani.html
# https://maladkshetrasamiti-sketch.github.io/maladutsav2025/program/vivahsamiti/output/CL_vivahsamiti_NeerajSarda.html
# ✅ Dashboard created successfully: dashboard_vivahsamiti.html

# %%
from fileinput import filename
import pandas as pd
import os
import urllib.parse
import pdfkit
import re

# === CONFIG ===

# === CONFIG ===
input_csv = karykarta_assignment_list   # CSV file with data
output_folder = karykarta_assignment_list_output_folder    # Folder for HTML output


# === CREATE OUTPUT FOLDER IF NOT EXISTS ===
os.makedirs(output_folder, exist_ok=True)

# === READ CSV ===
df = pd.read_csv(input_csv)
# Clean column names if needed
df.columns = df.columns.str.strip()

dfCallLog = pd.read_csv(call_log_data_csv)
dfCallLog.columns = dfCallLog.columns.str.strip()
dfCallLog["Timestamp"] = pd.to_datetime(dfCallLog["Timestamp"], errors="coerce")
dfCallLog = (
    dfCallLog[dfCallLog["Program Name"] == Program_Name]
    [["Timestamp", "Phone Number", "Call Status ?"]]
    .sort_values("Timestamp")  # oldest -> newest
    .drop_duplicates(subset="Phone Number", keep="last")
    .copy()
)

def normalize_phone(s):
    if pd.isna(s):
        return ""
    return str(s).strip().replace(" ", "")

# remove non-digit characters (keeps only 0-9)
dfCallLog["Phone_norm"] = dfCallLog["Phone Number"].astype(str).str.replace(r"\D+", "", regex=True)
df["Mobile_norm"] = df["Mobile Number"].astype(str).str.replace(r"\D+", "", regex=True)

df = df.merge(
    dfCallLog[["Timestamp", "Phone_norm", "Call Status ?"]],
    left_on="Mobile_norm",
    right_on="Phone_norm",
    how="left",
    suffixes=("", "_calllog")
)

# 6) Clean up helper columns (if you don't need them)
df = df.drop(columns=["Mobile_norm", "Phone_norm"])

df.head()

# === PROCESS EACH SAMITI MEMBER ===
for samiti_member_name, group in df.groupby("Samiti Member Name"):
    
    filepath = html_file_name_samiti_member(samiti_member_name)

    print(f"Generating calling list for: {samiti_member_name} -> {filepath}")
    

    # Start HTML content
    html = f"""
    <html>
    <head>
        <meta charset="UTF-8">
        <title>Calling List - {samiti_member_name}</title>
        <style>
            body {{ font-family: Arial, sans-serif; margin: 20px; }}
            h2 {{ text-align: center; }}
            table {{ width: 100%; border-collapse: collapse; margin-top: 20px; }}
            th, td {{ border: 1px solid #ccc; padding: 8px; text-align: left; }}
            th {{ background-color: #f2f2f2; }}
            a {{ color: #007bff; text-decoration: none; }}
            a:hover {{ text-decoration: underline; }}
        </style>
    </head>
    <body>
        <img src="{image_path}" alt="Malad Kshetra Samiti Logo" style="display:block; margin-left:auto; margin-right:auto; width:100px; height:auto;">
        <h2>Calling List - {samiti_member_name}</h2>
        <div style="font-family: Arial, sans-serif; color: #333; line-height: 1.4; padding: 8px; max-width: 100%; box-sizing: border-box; font-size: 14px;">
            <p style="font-weight: bold; margin-bottom: 6px; font-size: 15px;">
                कृपया निम्नलिखित सरल चरणों का पालन करें:
            </p>
            <ul style="padding-left: 18px; margin: 0; font-size: 8px;">
                <li><strong>Mobile Number</strong> पर क्लिक करें &mdash; कॉल अपने आप डायल हो जाएगी</li>
                <li><strong>SMS</strong> पर क्लिक करें &mdash; आपके मोबाइल से आमंत्रण संदेश जाएगा</li>
                <li><strong>WhatsApp</strong> पर क्लिक करें &mdash; व्हाट्सएप खुलेगा और संदेश अपने आप पोस्ट हो जाएगा</li>
                <li>आप समाजबंधु को <strong>{Program_Name}</strong> की जानकारी दें</li>
            </ul>
        </div>        
        <table>
            <tr>
                <th>#</th>
                <th>Assigned Person Name</th>
                <th>Mobile Number</th>
                <th>WahtsApp Message</th>
                <th>SMS</th>
                <th>Call Status</th>
                <th>As of</th>
                <th>Call Log Link</th>
            </tr>
    """
    # Sort the group DataFrame by 'Assigned Person' alphabetically
    group_sorted = group.sort_values(by="Assigned Person")
    i = 1
    for _, row in group_sorted.iterrows():
        assigned_person = row["Assigned Person"]
        call_status = row["Call Status ?"]
        if pd.isna(call_status):
            call_status = "Not Called"
        as_of = row["Timestamp"]
        row_color = "#ffe6e6" if call_status.lower() == "not called" else "#e8ffe8"
        row_color = "#ffe6e6" if call_status.lower() == "not called" else "#e6ffe6"

        print(call_status, row_color)

        # Custom WhatsApp message

        whatsapp_message = event_message_in_person.format(assigned_person, samiti_member_name)
        #     "🙏 Jai Mahesh!\n"
        #     f"Namskar {assigned_person} ji,\n\n"
        #     "Welcome to *Malad Utsav 2025* 🎉\n\n"
        #     "📅 Date: 9 Nov 2025 (Sunday)\n"
        #     "🕠 Time: 5:30 PM Onwards\n"
        #     "📍 Venue: Maheshwari Plot, Borivali (W)\n\n"
        #     "Please confirm your participation using the google form below 👇\n"
        #     "https://forms.gle/Asvp6qqAv5utMb1x8 \n\n"
        #     "For Marksheet submission:   👇\n"
        #     "https://forms.gle/YgKUfYDDkNWTYJHUA \n\n"
        #     "if you face any issues with marksheet submission, Whatsapp  # 9820454734\n\n"
        #     f"For any queries, contact Karykarta {samiti_member_name}.\n\n"
        # )
        
        # Encode the message for URL
        encoded_whatsapp_message = urllib.parse.quote_plus(whatsapp_message)
        
        mobile = str(row["Mobile Number"]).strip()

        # Encode for URL
        encoded_person = urllib.parse.quote(assigned_person)
        encoded_mobile = urllib.parse.quote(mobile)
        encoded_samiti = urllib.parse.quote(samiti_member_name)
        #encoded_address = urllib.parse.quote(Address)

        # Google Form Prefilled Link
        call_log_link = (
            f"{form_url_base}"
            f"&entry.752647600=Called"
            f"&entry.1573933320={encoded_samiti}"
            f"&entry.1585817478={encoded_mobile}"
            f"&entry.1475012068={encoded_person}"
            f"&entry.410440017={Program_Name}"
        )

        
        # Create tel: and WhatsApp links
        tel_link = f"<a onclick=\"this.style.color='green'\" href='tel:+91{mobile}'>+91 {mobile}</a>"
        # SMS link
        sms_link = f'<a href="sms:+91{mobile}?body={encoded_whatsapp_message}" target="_blank" onclick="this.style.color=\'green\'">SMS</a>'

        # WhatsApp link
        whatsapp_link = f'<a href="https://wa.me/91{mobile}?text={encoded_whatsapp_message}" target="_blank" onclick="this.style.color=\'green\'">WhatsApp</a>'


        html += f"""
            <tr style="background-color: {row_color};">
                <td>{i}</td>
                <td>{assigned_person}</td>
                <td>{tel_link}</td>
                <td>{whatsapp_link}</td>
                <td>{sms_link}</td>
                <td>{call_status}</td>
                <td>{as_of}</td>
                <td><a onclick=\"this.style.color='green'\" href="{call_log_link}" target="_blank">Log Call</a></td>
            </tr>
        """
        i = i+1

    html += """
        </table>
    </body>
    </html>
    """
    # from weasyprint import HTML
    # Save the HTML file
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(html)

    # Convert local HTML file to PDF
    # HTML(filepath).write_pdf(pdf_filepath)

print(f"✅ HTML files successfully created in folder: {output_folder}")
# Out:
# Generating calling list for: Ashish Mundada  -> program\vivahsamiti\output\CL_vivahsamiti_AshishMundada.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Maybe Attending 🤔 #e6ffe6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Jyoti Rathi  -> program\vivahsamiti\output\CL_vivahsamiti_JyotiRathi.html
# Confirmed Presence ✅ #e6ffe6
# Not Called #ffe6e6
# Maybe Attending 🤔 #e6ffe6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Kanta Malpani -> program\vivahsamiti\output\CL_vivahsamiti_KantaMalpani.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Krishna zawar -> program\vivahsamiti\output\CL_vivahsamiti_Krishnazawar.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Neeraj Sarda -> program\vivahsamiti\output\CL_vivahsamiti_NeerajSarda.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Seema Chitlangia  -> program\vivahsamiti\output\CL_vivahsamiti_SeemaChitlangia.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Shanuji kabra  -> program\vivahsamiti\output\CL_vivahsamiti_Shanujikabra.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Generating calling list for: Varoon Jajoo -> program\vivahsamiti\output\CL_vivahsamiti_VaroonJajoo.html
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# Not Called #ffe6e6
# ✅ HTML files successfully created in folder: program\vivahsamiti\output\

# %%
df.head()
# Out:
#   Samiti Member Name   Assigned Person  Mobile Number           Timestamp  \
# 0       Jyoti Rathi   AAKANKSHA LAHOTI     9820268007 2025-12-04 20:46:42
# 1    Ashish Mundada    AANCHAL MALPANI     7467062051                 NaT
# 2     Shanuji kabra      AANCHAL KABRA     9867122621                 NaT
# 3      Krishna zawar     AARTI JHANWAR     9664390480                 NaT
# 4  Seema Chitlangia        AARTI RATHI     9920392532                 NaT
#
#           Call Status ?
# 0  Confirmed Presence ✅
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# import pandas as pd
# import os
# import urllib.parse
# import re

# # === CONFIG ===
# input_csv = karykarta_assignment_list   # CSV file with data
# output_folder = karykarta_assignment_list_output_folder    # Folder for HTML output
# github_base_url = "https://maladkshetrasamiti-sketch.github.io/maladutsav2025"  # Replace with your actual GitHub Pages URL
# form_url_base = (
#     "https://docs.google.com/forms/d/e/1FAIpQLSddgJb-7qSWjw4vIjB-6rAddcIrCSTreRmbnNNAst2I_bd8dA/viewform?usp=pp_url"
# )

# # === CREATE OUTPUT FOLDER IF NOT EXISTS ===
# os.makedirs(output_folder, exist_ok=True)

# # === READ CSV ===
# df = pd.read_csv(input_csv)
# df.columns = df.columns.str.strip()

# # === PROCESS EACH SAMITI MEMBER ===
# for samiti_member_name, group in df.groupby("Samit Member Name"):

#     name_link = html_file_name_samiti_member(samiti_member_name)
#     name_link_full = f"https://maladkshetrasamiti-sketch.github.io/maladutsav2025/{name_link}"

#     filename = os.path.join(output_folder, name_link)

#     # GitHub hosted link

#     html = f"""
#     <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Calling List - {samiti_member_name} Ji </title>
#         <style>
#             body {{ font-family: Arial, sans-serif; margin: 20px; }}
#             h2 {{ text-align: center; }}
#             table {{ width: 100%; border-collapse: collapse; margin-top: 20px; }}
#             th, td {{ border: 1px solid #ccc; padding: 8px; text-align: left; }}
#             th {{ background-color: #f2f2f2; }}
#             a {{ color: #007bff; text-decoration: none; }}
#             a:hover {{ text-decoration: underline; }}
#         </style>
#     </head>
#     <body>
#         <h2>Calling List - {samiti_member_name} Ji </h2>
#         <table>
#             <tr>
#                 <th>#</th>
#                 <th>Assigned Person Name</th>
#                 <th>Mobile Number</th>
#                 <th>Whats App</th>
#                 <th>SMS</th>
#             </tr>
#     """

#     group_sorted = group.sort_values(by="Assigned Person")
#     i = 1
#     for _, row in group_sorted.iterrows():
#         assigned_person = row["Assigned Person"]
        
#         # Ensure proper URL encoding
#         encoded_filename = urllib.parse.quote(filename, safe="/")
#         github_link = f"{github_base_url}/{encoded_filename}"

#         mobile = str(row["Mobile Number"]).strip()

#         # WhatsApp message with GitHub link
#         # WhatsApp message with GitHub link (Motivating + Polite)
#         whatsapp_message = (
#             "🙏 *Jai Mahesh!*\n"
#             f"प्रिय कार्यकर्ता {assigned_person} जी,\n\n"
#             "आप *Malad Utsav 2025* 🎉 के इस भव्य आयोजन के अभिन्न अंग हैं।\n"
#             "This is Fresh List and we have to call them in next 2 days.\n"
#             "आपको जिन समाजबंधुओं से संपर्क कर आमंत्रण देना है, उनकी सूची नीचे दिए गए लिंक पर उपलब्ध है 👇\n"
#             f"{github_link}\n\n"
#             "💡 कृपया निम्नलिखित सरल चरणों का पालन करें:\n"
#             "1️⃣ *Mobile Number* पर क्लिक करें — कॉल अपने आप डायल हो जाएगी 📞\n"
#             "2️⃣ *SMS* पर क्लिक करें — आपके मोबाइल से आमंत्रण संदेश जाएगा ✉️\n"
#             "3️⃣ *WhatsApp* पर क्लिक करें — व्हाट्सएप खुलेगा और संदेश अपने आप पोस्ट हो जाएगा 💬\n"
#             "4️⃣ समाजबंधु से बात करने के बाद *Log Call* पर क्लिक करें ताकि आपकी कॉल का विवरण सीधे Google Form पर सेव हो जाए ✅\n\n"
#             "📅 *कार्यक्रम तिथि:* 9 नवम्बर 2025 (रविवार)\n"
#             "🕠 *समय:* शाम 5:30 बजे से आगे\n"
#             "📍 *स्थान:* महेश्वरी प्लॉट, बोरिवली (पश्चिम)\n\n"
#             "आपका यह छोटा सा प्रयास हमारे समाज के इस महोत्सव को और भी सफल बनाएगा 🙏\n"
#             "कृपया अधिक से अधिक समाजबंधुओं को *Malad Utsav 2025* में आमंत्रित करें और उन्हें परिवार सहित आने के लिए प्रेरित करें 🌸\n\n"
#             "सादर धन्यवाद,\n"
#             "*Malad Kshetriya Samiti परिवार* 💐"
#         )


#         encoded_message = urllib.parse.quote_plus(whatsapp_message)
#         whatsapp_link = f"https://wa.me/91{mobile}?text={encoded_message}"
#         tel_link = f"<a href='tel:+91{mobile}'>+91 {mobile}</a>"

#         # # Prefilled Google Form Link
#         # call_log_link = (
#         #     f"{form_url_base}"
#         #     f"&entry.752647600=Called"
#         #     f"&entry.1475012068={urllib.parse.quote_plus(assigned_person)}"
#         #     f"&entry.1585817478={urllib.parse.quote_plus(mobile)}"
#         #     f"&entry.1573933320={urllib.parse.quote_plus(samiti_name)}"
#         # )

#         html += f"""
#             <tr>
#                 <td>{i}</td>
#                 <td>{assigned_person}</td>
#                 <td>{tel_link} | <a onclick=\"this.style.color='green'\" href="{whatsapp_link}" target="_blank">WhatsApp</a></td>
#                 <td><a href="{github_link}" onclick=\"this.style.color='green'\" target="_blank">GitHub</a></td>
#             </tr>
#         """
#         i += 1

#     html += """
#         </table>
#     </body>
#     </html>
#     """

#     # Save HTML file
#     with open(filepath, "w", encoding="utf-8") as f:
#         f.write(html)

# print(f"✅ HTML files created in folder: {output_folder}")
# print(f"✅ Each WhatsApp message now contains its GitHub file link.")
